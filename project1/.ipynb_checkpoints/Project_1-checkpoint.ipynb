# %%
library(lubridate)
# Out:
# Attaching package: 'lubridate'
#
#
# The following objects are masked from 'package:base':
#
#     date, intersect, setdiff, union

# %%
cta_data_part1 <- read.table(file = 'CTA_-_Ridership_-__L__Station_Entries_-_Daily_Totals.tsv', sep = '\t', header = TRUE)
# Out:
# Warning message in scan(file = file, what = what, sep = sep, quote = quote, dec = dec, :
# "EOF within quoted string"
# Warning message in scan(file = file, what = what, sep = sep, quote = quote, dec = dec, :
# "number of items read is not a multiple of the number of columns"

# %%
cta_data
# Out:
#       ï..station_id stationname
# 1     41280         Jefferson Park
# 2     41000         Cermak-Chinatown
# 3     40280         Central-Lake
# 4     40140         Dempster-Skokie
# 5     40690         Dempster
# 6     41660         Lake/State
# 7     40180         Oak Park-Forest Park
# 8     40250         Kedzie-Homan-Forest Park
# 9     40120         35th/Archer
# 10    41420         Addison-North Main
# 11    40270         Main
# 12    41450         Chicago/State
# 13    41210         Wellington
# 14    40010         Austin-Forest Park
# 15    41160         Clinton-Lake
# 16    40720         East 63rd-Cottage Grove
# 17    40330         Grand/State
# 18    40540         Wilson
# 19    40420         Cicero-Cermak
# 20    40260         State/Lake
# 21    40130         51st
# 22    40450         95th/Dan Ryan
# 23    40560         Jackson/State
# 24    40200         Randolph/Wabash
# 25    40690         Dempster
# 26    41020         Logan Square
# 27    40100         Morse
# ...

# %%
cta_data <- read.table(file = 'CTA_-_Ridership_-__L__Station_Entries_-_Daily_Totals_part10.tsv', sep = '\t', header = TRUE)

# %%
cta_data
# Out:
#      X41490 Harrison          X09.05.2021 U   X2197
# 1    41490  Harrison          09/06/2021  U   1573
# 2    41490  Harrison          09/07/2021  W   2244
# 3    41490  Harrison          09/08/2021  W   2416
# 4    41490  Harrison          09/09/2021  W   2438
# 5    41490  Harrison          09/10/2021  W   2815
# 6    41490  Harrison          09/11/2021  A   2737
# 7    41490  Harrison          09/12/2021  U   1892
# 8    41490  Harrison          09/13/2021  W   2208
# 9    41490  Harrison          09/14/2021  W   2403
# 10   41490  Harrison          09/15/2021  W   2480
# 11   41490  Harrison          09/16/2021  W   2754
# 12   41490  Harrison          09/17/2021  W   3036
# 13   41490  Harrison          09/18/2021  A   2557
# 14   41490  Harrison          09/19/2021  U   1915
# 15   41490  Harrison          09/20/2021  W   2138
# 16   41490  Harrison          09/21/2021  W   2373
# 17   41490  Harrison          09/22/2021  W   2435
# ...
